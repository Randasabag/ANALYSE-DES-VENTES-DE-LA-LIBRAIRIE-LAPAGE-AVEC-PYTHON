# %% [markdown]
# <a href="https://colab.research.google.com/github/Randasabag/ANALYSE-DES-VENTES-DE-LA-LIBRAIRIE-LAPAGE-AVEC-PYTHON/blob/main/projet9V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='indianred'> LA POULE QUI CHANTE </font>
# ##MISSION : Analyse pour le lancement à l’international en groupant les pays à cibler pour exporter nos poulets
#
# 1ère partie : Prétraitement des données
#
#
# 2ème partie : Analyse
# <li>ACP afin de visualiser les résultats de ton analyse, comprendre les groupes, les liens entre les variables, les liens entre les individus</li>
# <li>Méthode des k-means, afin d’affiner l’analyse et comparer les résultats des deux méthodes de clustering et analyse des centroides des classes</li>
# <li>Classification ascendante hiérarchique avec un dendrogramme comme visualisation</li>
#
#
# # Sommaire :
# **Partie 1 : Importation des données**
#  - <a href="#C1">Importation des librairies</a>
#  - <a href="#C2">Importation des jeux de données</a>
#
# **Partie 2 : Analyse des jeux de données**
#  - <a href="#C3">Affichage du nombre de lignes et colonnes des jeux de données </a>
#  - <a href="#C4">Affichage des informations des jeux de données </a>
#  - <a href="#C5">Analyse des valeurs manquantes</a>
#  - <a href="#C6">Unicité de la clé primaire</a>
#  - <a href="#C7">Analyse des doublons</a>
#  - <a href="#C8">Jointure des tables</a>
#  - <a href="#C9">Indicateurs choisis</a>
#
#
#
# **Partie 3 : Analyse univariée des indicateurs**
#  - <a href="#C10">Disponibilité alimentaire</a>
#  - <a href="#C11">Importations</a>
#  - <a href="#C12">Production</a>
#  - <a href="#C13">Population</a>
#  - <a href="#C14">PIB/Habitant</a>
#  - <a href="#C15">Indice de stabilité politique</a>
#
#
# **Partie 4 : Analyse bivariée des indicateurs**
#  - <a href="#C16">Disponibilité alimentaire/Importations</a>
#  - <a href="#C17">Disponibilité alimentaire/Production</a>
#  - <a href="#C18">Importations/Production</a>
#  - <a href="#C19">Importations/Population</a>
#  - <a href="#C20">Indice de stabilité politique/PIB par Habitant</a>
#
# **Partie 5 : Analyse bivariée des indicateurs**
#  - <a href="#C21"></a>

# %% [markdown]
# # **<font color='indianred'>Partie 1 : Importation des données</font>**

# %% [markdown]
# # <a name="C1"><font color='LightSeaGreen'>Importation des librairies</font></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import io
from google.colab import files

# %% [markdown]
# # <a name="C2"><font color='LightSeaGreen'>Importation des données</font></a>

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2dc34d6c-e1ba-44a6-b149-c053c3385024" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2dc34d6c-e1ba-44a6-b149-c053c3385024">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DisponibiliteAlimentaire_2017.csv to DisponibiliteAlimentaire_2017.csv
# Saving pibindice.csv to pibindice.csv
# Saving Population_2000_2018.csv to Population_2000_2018.csv

# %%
#Disponibilité alimentaire pour l'année 2017
df_dispo=pd.read_csv(io.BytesIO(uploaded['DisponibiliteAlimentaire_2017.csv'])) 
df_dispo.head()
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
#
#    Code Élément                   Élément  Code Produit          Produit  \
# 0          5511                Production          2511  Blé et produits
# 1          5611   Importations - Quantité          2511  Blé et produits
# 2          5072        Variation de stock          2511  Blé et produits
# 3          5911   Exportations - Quantité          2511  Blé et produits
# 4          5301  Disponibilité intérieure          2511  Blé et produits
#
#    Code année  Année               Unité  Valeur Symbole  \
# 0        2017   2017  Milliers de tonnes  4281.0       S
# 1        2017   2017  Milliers de tonnes  2302.0       S
# 2        2017   2017  Milliers de tonnes  -119.0       S
# 3        2017   2017  Milliers de tonnes     0.0       S
# 4        2017   2017  Milliers de tonnes  6701.0       S
#
#   Description du Symbole
# 0  Données standardisées
# 1  Données standardisées
# 2  Données standardisées
# 3  Données standardisées
# 4  Données standardisées

# %%
#Population entre les années 2000 et 2018
df_pop=pd.read_csv(io.BytesIO(uploaded['Population_2000_2018.csv'])) 
df_pop.head()
# Out:
#   Code Domaine                       Domaine  Code zone         Zone  \
# 0           OA  Séries temporelles annuelles          2  Afghanistan
# 1           OA  Séries temporelles annuelles          2  Afghanistan
# 2           OA  Séries temporelles annuelles          2  Afghanistan
# 3           OA  Séries temporelles annuelles          2  Afghanistan
# 4           OA  Séries temporelles annuelles          2  Afghanistan
#
#    Code Élément            Élément  Code Produit                 Produit  \
# 0           511  Population totale          3010  Population-Estimations
# 1           511  Population totale          3010  Population-Estimations
# 2           511  Population totale          3010  Population-Estimations
# 3           511  Population totale          3010  Population-Estimations
# 4           511  Population totale          3010  Population-Estimations
#
#    Code année  Année           Unité     Valeur Symbole  \
# 0        2000   2000  1000 personnes  20779.953       X
# 1        2001   2001  1000 personnes  21606.988       X
# 2        2002   2002  1000 personnes  22600.770       X
# 3        2003   2003  1000 personnes  23680.871       X
# 4        2004   2004  1000 personnes  24726.684       X
#
#           Description du Symbole Note
# 0  Sources internationales sûres  NaN
# 1  Sources internationales sûres  NaN
# 2  Sources internationales sûres  NaN
# 3  Sources internationales sûres  NaN
# 4  Sources internationales sûres  NaN

# %%
#Tableau regroupant les données sur le PIB/habitant et l'indice de stabilité politique
df_pibind=pd.read_csv(io.BytesIO(uploaded['pibindice.csv'])) 
df_pibind.head()
# Out:
#   Code Domaine                             Domaine  Code zone (FAO)  \
# 0           FS  Données de la sécurité alimentaire                2
# 1           FS  Données de la sécurité alimentaire                2
# 2           FS  Données de la sécurité alimentaire              202
# 3           FS  Données de la sécurité alimentaire              202
# 4           FS  Données de la sécurité alimentaire                3
#
#              Zone  Code Élément Élément  Code Produit  \
# 0     Afghanistan          6126  Valeur         22013
# 1     Afghanistan          6125  Valeur         21032
# 2  Afrique du Sud          6126  Valeur         22013
# 3  Afrique du Sud          6125  Valeur         21032
# 4         Albanie          6126  Valeur         22013
#
#                                              Produit  Code année  Année  \
# 0  PIB par habitant, ($ PPA internationaux consta...        2017   2017
# 1  Stabilité politique et absence de violence/ter...        2017   2017
# 2  PIB par habitant, ($ PPA internationaux consta...        2017   2017
# 3  Stabilité politique et absence de violence/ter...        2017   2017
# 4  PIB par habitant, ($ PPA internationaux consta...        2017   2017
#
#     Unité    Valeur Symbole         Description du Symbole  Note
# 0      I$   2058.40       X  Sources internationales sûres   NaN
# 1  indice     -2.80       X  Sources internationales sûres   NaN
# 2      I$  12701.30       X  Sources internationales sûres   NaN
# 3  indice     -0.28       X  Sources internationales sûres   NaN
# 4      I$  12771.00       X  Sources internationales sûres   NaN

# %% [markdown]
# ##<font color='purple'>Préparation des données</font>

# %% [markdown]
# ### Table Disponibilité Alimentaire

# %%
#La table Disponibilité Alimentaire contient des données pour l'année 2017
#Garder la viande de volailles 
df_dispovol=df_dispo[df_dispo['Produit']=='Viande de Volailles']     
#renomme la colonne zone par pays
df_dispovol=df_dispovol.rename(columns={'Zone':'Pays'})   
df_dispovol.head()
# Out:
#     Code Domaine                      Domaine  Code zone         Pays  \
# 651          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 652          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 653          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 654          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 655          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
#
#      Code Élément                   Élément  Code Produit  \
# 651          5511                Production          2734
# 652          5611   Importations - Quantité          2734
# 653          5072        Variation de stock          2734
# 654          5301  Disponibilité intérieure          2734
# 655          5123                    Pertes          2734
#
#                  Produit  Code année  Année               Unité  Valeur  \
# 651  Viande de Volailles        2017   2017  Milliers de tonnes    28.0
# 652  Viande de Volailles        2017   2017  Milliers de tonnes    29.0
# 653  Viande de Volailles        2017   2017  Milliers de tonnes     0.0
# 654  Viande de Volailles        2017   2017  Milliers de tonnes    57.0
# 655  Viande de Volailles        2017   2017  Milliers de tonnes     2.0
#
#     Symbole Description du Symbole
# 651       S  Données standardisées
# 652       S  Données standardisées
# 653       S  Données standardisées
# 654       S  Données standardisées
# 655       S  Données standardisées

# %%
df_dispovol=df_dispovol[['Pays', 'Élément', 'Unité', 'Valeur']]
df_dispovol.head()
# Out:
#             Pays                   Élément               Unité  Valeur
# 651  Afghanistan                Production  Milliers de tonnes    28.0
# 652  Afghanistan   Importations - Quantité  Milliers de tonnes    29.0
# 653  Afghanistan        Variation de stock  Milliers de tonnes     0.0
# 654  Afghanistan  Disponibilité intérieure  Milliers de tonnes    57.0
# 655  Afghanistan                    Pertes  Milliers de tonnes     2.0

# %%
df_dispovol=df_dispovol.pivot_table(index='Pays', columns='Élément', values='Valeur', aggfunc=sum)
df_dispovol.head()
# Out:
# Élément         Alimentation pour touristes  Aliments pour animaux  \
# Pays
# Afghanistan                             NaN                    NaN
# Afrique du Sud                          0.0                    NaN
# Albanie                                 NaN                    NaN
# Algérie                                 0.0                    NaN
# Allemagne                               NaN                    NaN
#
# Élément         Autres utilisations (non alimentaire)  \
# Pays
# Afghanistan                                       NaN
# Afrique du Sud                                    NaN
# Albanie                                           NaN
# Algérie                                           NaN
# Allemagne                                         NaN
#
# Élément         Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Afghanistan                                                5.0
# Afrique du Sud                                           143.0
# Albanie                                                   85.0
# Algérie                                                   22.0
# Allemagne                                                 71.0
#
# Élément         Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Afghanistan                                                  1.53
# Afrique du Sud                                              35.69
# Albanie                                                     16.36
# Algérie                                                      6.38
# Allemagne                                                   19.47
#
# Élément         Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                  0.33
# Afrique du Sud                                               9.25
# Albanie                                                      6.45
# Algérie                                                      1.50
# Allemagne                                                    4.16
#
# Élément         Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                  0.54
# Afrique du Sud                                              14.11
# Albanie                                                      6.26
# Algérie                                                      1.97
# Allemagne                                                    7.96
#
# Élément         Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Afghanistan                         57.0                      NaN
# Afrique du Sud                    2118.0                     63.0
# Albanie                             47.0                      0.0
# Algérie                            277.0                      0.0
# Allemagne                         1739.0                    646.0
#
# Élément         Importations - Quantité  Nourriture  Pertes  Production  \
# Pays
# Afghanistan                        29.0        55.0     2.0        28.0
# Afrique du Sud                    514.0      2035.0    83.0      1667.0
# Albanie                            38.0        47.0     NaN        13.0
# Algérie                             2.0       264.0    13.0       275.0
# Allemagne                         842.0      1609.0     NaN      1514.0
#
# Élément         Résidus  Semences  Traitement  Variation de stock
# Pays
# Afghanistan         0.0       NaN         NaN                 0.0
# Afrique du Sud      0.0       NaN         NaN                 0.0
# Albanie             0.0       NaN         NaN                 4.0
# Algérie             0.0       NaN         NaN                 0.0
# Allemagne         -38.0       NaN       167.0               -29.0

# %%
df_dispovol=df_dispovol.reset_index()
df_dispovol=df_dispovol[['Pays', 'Disponibilité alimentaire en quantité (kg/personne/an)', 'Disponibilité intérieure', 'Exportations - Quantité',	'Importations - Quantité', 'Production', 'Variation de stock']]
df_dispovol.head(2)
# Out:
# Élément            Pays  \
# 0           Afghanistan
# 1        Afrique du Sud
#
# Élément  Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                     1.53
# 1                                                    35.69
#
# Élément  Disponibilité intérieure  Exportations - Quantité  \
# 0                            57.0                      NaN
# 1                          2118.0                     63.0
#
# Élément  Importations - Quantité  Production  Variation de stock
# 0                           29.0        28.0                 0.0
# 1                          514.0      1667.0                 0.0

# %%
df_dispovol=df_dispovol.rename(columns={'Disponibilité alimentaire en quantité (kg/personne/an)':'Disponibilité alimentaire', 'Exportations - Quantité' : 'Exportations', 'Importations - Quantité':'Importations'})

# %% [markdown]
# ### Table Population

# %%
#Garder l'année 2017 
df_pop2017=df_pop[df_pop['Année']==2017]        
df_pop2017.head()
# Out:
#    Code Domaine                       Domaine  Code zone            Zone  \
# 17           OA  Séries temporelles annuelles          2     Afghanistan
# 36           OA  Séries temporelles annuelles        202  Afrique du Sud
# 55           OA  Séries temporelles annuelles          3         Albanie
# 74           OA  Séries temporelles annuelles          4         Algérie
# 93           OA  Séries temporelles annuelles         79       Allemagne
#
#     Code Élément            Élément  Code Produit                 Produit  \
# 17           511  Population totale          3010  Population-Estimations
# 36           511  Population totale          3010  Population-Estimations
# 55           511  Population totale          3010  Population-Estimations
# 74           511  Population totale          3010  Population-Estimations
# 93           511  Population totale          3010  Population-Estimations
#
#     Code année  Année           Unité     Valeur Symbole  \
# 17        2017   2017  1000 personnes  36296.113       X
# 36        2017   2017  1000 personnes  57009.756       X
# 55        2017   2017  1000 personnes   2884.169       X
# 74        2017   2017  1000 personnes  41389.189       X
# 93        2017   2017  1000 personnes  82658.409       X
#
#            Description du Symbole Note
# 17  Sources internationales sûres  NaN
# 36  Sources internationales sûres  NaN
# 55  Sources internationales sûres  NaN
# 74  Sources internationales sûres  NaN
# 93  Sources internationales sûres  NaN

# %%
df_pop2017=df_pop2017[['Zone', 'Unité', 'Valeur']]
df_pop2017.head()
# Out:
#               Zone           Unité     Valeur
# 17     Afghanistan  1000 personnes  36296.113
# 36  Afrique du Sud  1000 personnes  57009.756
# 55         Albanie  1000 personnes   2884.169
# 74         Algérie  1000 personnes  41389.189
# 93       Allemagne  1000 personnes  82658.409

# %%
#renomme la colonne zone par pays
df_pop2017=df_pop2017.rename(columns={'Zone':'Pays', 'Valeur':'Population'}) 
df_pop2017.head()
# Out:
#               Pays           Unité  Population
# 17     Afghanistan  1000 personnes   36296.113
# 36  Afrique du Sud  1000 personnes   57009.756
# 55         Albanie  1000 personnes    2884.169
# 74         Algérie  1000 personnes   41389.189
# 93       Allemagne  1000 personnes   82658.409

# %%
df_pop2017['Population']=df_pop2017['Population'] * 1000
df_pop2017.head()
# Out:
#               Pays           Unité  Population
# 17     Afghanistan  1000 personnes  36296113.0
# 36  Afrique du Sud  1000 personnes  57009756.0
# 55         Albanie  1000 personnes   2884169.0
# 74         Algérie  1000 personnes  41389189.0
# 93       Allemagne  1000 personnes  82658409.0

# %%
df_pop2017=df_pop2017[['Pays', 'Population']]
df_pop2017.head()
# Out:
#               Pays  Population
# 17     Afghanistan  36296113.0
# 36  Afrique du Sud  57009756.0
# 55         Albanie   2884169.0
# 74         Algérie  41389189.0
# 93       Allemagne  82658409.0

# %% [markdown]
# ### Table PIB et Indice de stabilité politique

# %%
#df_pibind.head(2)

# %%
df_pibind=df_pibind.pivot_table(index='Zone', columns='Produit', values='Valeur', aggfunc=sum)
df_pibind.head()
# Out:
# Produit         PIB par habitant, ($ PPA internationaux constants de 2011)  \
# Zone
# Afghanistan                                                2058.4
# Afrique du Sud                                            12701.3
# Albanie                                                   12771.0
# Algérie                                                   11737.4
# Allemagne                                                 52952.9
#
# Produit         Stabilité politique et absence de violence/terrorisme (indice)
# Zone
# Afghanistan                                                 -2.80
# Afrique du Sud                                              -0.28
# Albanie                                                      0.38
# Algérie                                                     -0.92
# Allemagne                                                    0.59

# %%
df_pibind=df_pibind.reset_index()
#renomme la colonne zone par pays
df_pibind=df_pibind.rename(columns={'Zone':'Pays', 'PIB par habitant, ($ PPA internationaux constants de 2011)' : 'PIB/Hab', 'Stabilité politique et absence de violence/terrorisme (indice)': 'Indice de stabilité'}) 
df_pibind.head()
# Out:
# Produit            Pays  PIB/Hab  Indice de stabilité
# 0           Afghanistan   2058.4                -2.80
# 1        Afrique du Sud  12701.3                -0.28
# 2               Albanie  12771.0                 0.38
# 3               Algérie  11737.4                -0.92
# 4             Allemagne  52952.9                 0.59

# %% [markdown]
# # **<font color='indianred'>Partie 2 : Analyse des jeux de données</font>**

# %% [markdown]
# # <a name="C3"><font color='LightSeaGreen'>Affichage du nombre de lignes et colonnes des jeux de données</font></a>

# %%
#nombre de lignes et colonnes
print('Disponibilité alimentaire',df_dispovol.shape)
print('Population',df_pop2017.shape)
print('PIB_Indice',df_pibind.shape)
# Out:
# Disponibilité alimentaire (172, 7)
# Population (236, 2)
# PIB_Indice (198, 3)

# %% [markdown]
# # <a name="C4"><font color='LightSeaGreen'>Affichage des informations des jeux de données</font></a>

# %%
print('Table Disponibilité Alimentaire')
df_dispovol.info()
print('\n')
print('Table Population')
print('-------------------------------------')
df_pop2017.info()
print('\n')
print('Table PIB Indice')
print('-------------------------------------')
df_pibind.info()
# Out:
# Table Disponibilité Alimentaire
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Pays                       172 non-null    object
#  1   Disponibilité alimentaire  172 non-null    float64
#  2   Disponibilité intérieure   170 non-null    float64
#  3   Exportations               135 non-null    float64
#  4   Importations               170 non-null    float64
#  5   Production                 168 non-null    float64
#  6   Variation de stock         169 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 9.5+ KB
#
#
# Table Population
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236 entries, 17 to 4409
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pays        236 non-null    object
#  1   Population  236 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.5+ KB
#
#
# Table PIB Indice
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pays                 198 non-null    object
#  1   PIB/Hab              187 non-null    float64
#  2   Indice de stabilité  197 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# # <a name="C5"><font color='LightSeaGreen'>Analyse des valeurs manquantes</font></a>

# %%
#Création d'une fonction calculant le pourcentage de valeurs manquantes 
#et affichant une heatmap pour visualiser les valeurs manquantes 
def val_manq(df):
    ligne,colonne=df.shape
    nb_cell=ligne*colonne
    nb_null=df.isnull().sum().sum()
    prct=nb_null *100/nb_cell
    print('Nombre de valeurs manquantes =',nb_null)
    print('Nombre de cellulles totales =',nb_cell)
    print('Pourcentage de valeurs manquantes = ',round(prct,2),'%') 
    print('\n')
    #print('Pourcentage de valeurs manquantes avec le nombre de colonnes =\n',(df.isna().sum()).value_counts(ascending=True))
    #Calcul des pourcentages de valeurs manquantes par variable(colonne)
    print('\n')
    print('Pourcentage de valeurs manquantes par variable/colonne =\n', 
          (df.isna().sum()).sort_values(ascending=True))
    print('\n')

# %%
#Appel de la fonction val_manq 
#Affichage des pourcentages de valeurs manquantes des 2 jeux de données 
print('1-Table disponibilité alimentaire :')
val_manq(df_dispovol)
print('---------------------------------------')
print('2-Table population :')
val_manq(df_pop2017)
print('---------------------------------------')
print('3-Table PIB Indice :')
val_manq(df_pibind)
# Out:
# 1-Table disponibilité alimentaire :
# Nombre de valeurs manquantes = 48
# Nombre de cellulles totales = 1204
# Pourcentage de valeurs manquantes =  3.99 %
#
#
#
#
# Pourcentage de valeurs manquantes par variable/colonne =
#  Élément
# Pays                          0
# Disponibilité alimentaire     0
# Disponibilité intérieure      2
# Importations                  2
# Variation de stock            3
# Production                    4
# Exportations                 37
# dtype: int64
#
#
# ---------------------------------------
# 2-Table population :
# Nombre de valeurs manquantes = 0
# Nombre de cellulles totales = 472
# Pourcentage de valeurs manquantes =  0.0 %
#
#
#
#
# Pourcentage de valeurs manquantes par variable/colonne =
#  Pays          0
# Population    0
# dtype: int64
#
#
# ---------------------------------------
# 3-Table PIB Indice :
# Nombre de valeurs manquantes = 12
# Nombre de cellulles totales = 594
# Pourcentage de valeurs manquantes =  2.02 %
#
#
#
#
# Pourcentage de valeurs manquantes par variable/colonne =
#  Produit
# Pays                    0
# Indice de stabilité     1
# PIB/Hab                11
# dtype: int64

# %% [markdown]
# ##<font color='purple'>Affichage des valeurs manquantes et affectation de valeurs</font>

# %%
#affiche le df avec au moins une valeur manquante par ligne
df_dispovol_null = df_dispovol[df_dispovol.isnull().any(axis=1)]
df_dispovol_null
# Out:
# Élément                                   Pays  Disponibilité alimentaire  \
# 0                                  Afghanistan                       1.53
# 13                                     Bahamas                      43.17
# 14                                  Bangladesh                       1.50
# 23                                Burkina Faso                       2.27
# 26                                  Cabo Verde                      17.62
# 27                                    Cambodge                       2.34
# 40                                        Cuba                      23.72
# 43                                    Djibouti                       2.68
# 54                                      Gambie                       3.53
# 56                                     Grenade                      45.70
# 59                                      Guinée                       4.08
# 60                               Guinée-Bissau                       2.16
# 63                                       Haïti                       8.91
# 80                                    Kiribati                      17.98
# 89                                  Madagascar                       2.87
# 91                                      Malawi                       5.17
# 92                                    Maldives                      13.50
# 93                                        Mali                       2.83
# 97                                  Mauritanie                       5.14
# 99                                    Mongolie                       2.77
# 101                                 Mozambique                       3.59
# 108                         Nouvelle-Calédonie                      38.71
# 110                                      Népal                       1.99
# 113                                Ouzbékistan                       1.96
# 122                                      Pérou                      13.47
# 126                  République centrafricaine                       2.29
# 130      République démocratique populaire lao                      10.91
# 132                République-Unie de Tanzanie                       1.88
# 134            Saint-Vincent-et-les Grenadines                      72.31
# 135                               Sainte-Lucie                      56.69
# 137                       Sao Tomé-et-Principe                       9.47
# 142                                     Soudan                       1.60
# 148                                Tadjikistan                       4.45
# 152                                Timor-Leste                       4.24
# 156                               Turkménistan                       4.52
# 160                                    Vanuatu                      11.66
# 165                                   Zimbabwe                       4.68
# 170                                   Éthiopie                       0.13
#
# Élément  Disponibilité intérieure  Exportations  Importations  Production  \
# 0                            57.0           NaN          29.0        28.0
# 13                           26.0           NaN          24.0         6.0
# 14                          250.0           NaN           0.0       249.0
# 23                           46.0           NaN           0.0        46.0
# 26                           10.0           NaN          12.0         1.0
# 27                           38.0           NaN          10.0        28.0
# 40                          342.0           NaN         312.0        29.0
# 43                            3.0           NaN           3.0         NaN
# 54                            8.0           NaN          16.0         2.0
# 56                            8.0           NaN           7.0         1.0
# 59                           50.0           NaN          37.0        13.0
# 60                            4.0           NaN           4.0         3.0
# 63                           98.0           NaN          89.0         9.0
# 80                            2.0           NaN           1.0         1.0
# 89                           82.0           NaN           0.0        81.0
# 91                           98.0           NaN           0.0       130.0
# 92                           12.0           NaN          12.0         NaN
# 93                           52.0           NaN           1.0        48.0
# 97                           22.0           NaN          24.0         5.0
# 99                            9.0           NaN          10.0         0.0
# 101                         116.0           NaN          24.0        92.0
# 108                          11.0           NaN           9.0         1.0
# 110                          58.0           NaN           0.0        58.0
# 113                           NaN           NaN           NaN         NaN
# 122                        1523.0           1.0          60.0      1465.0
# 126                          11.0           NaN           4.0         7.0
# 130                           NaN           NaN           NaN         NaN
# 132                         108.0           NaN           2.0       105.0
# 134                           8.0           NaN           9.0         0.0
# 135                          11.0           NaN          10.0         1.0
# 137                           2.0           NaN           2.0         1.0
# 142                          69.0           NaN           2.0        67.0
# 148                          40.0           NaN          38.0         2.0
# 152                           5.0           NaN          11.0         1.0
# 156                          27.0           NaN           9.0        20.0
# 160                           3.0           NaN           4.0         1.0
# 165                          76.0           NaN           6.0        69.0
# 170                          14.0           NaN           1.0        14.0
#
# Élément  Variation de stock
# 0                       0.0
# 13                      4.0
# 14                      0.0
# 23                      0.0
# 26                      4.0
# 27                      0.0
# 40                     -1.0
# 43                      0.0
# 54                     10.0
# 56                      0.0
# 59                      0.0
# 60                      3.0
# 63                      0.0
# 80                      0.0
# 89                      0.0
# 91                     33.0
# 92                      0.0
# 93                     -4.0
# 97                      6.0
# 99                      1.0
# 101                    -1.0
# 108                    -1.0
# 110                     0.0
# 113                     NaN
# 122                     NaN
# 126                     0.0
# 130                     NaN
# 132                     0.0
# 134                     1.0
# 135                     0.0
# 137                     1.0
# 142                     0.0
# 148                     0.0
# 152                     7.0
# 156                     2.0
# 160                     1.0
# 165                     0.0
# 170                     0.0

# %%
df_dispovol_null['Exportations']=df_dispovol_null['Production']+df_dispovol_null['Importations']+df_dispovol_null['Variation de stock']-df_dispovol_null['Disponibilité intérieure']
df_dispovol_null
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Élément                                   Pays  Disponibilité alimentaire  \
# 0                                  Afghanistan                       1.53
# 13                                     Bahamas                      43.17
# 14                                  Bangladesh                       1.50
# 23                                Burkina Faso                       2.27
# 26                                  Cabo Verde                      17.62
# 27                                    Cambodge                       2.34
# 40                                        Cuba                      23.72
# 43                                    Djibouti                       2.68
# 54                                      Gambie                       3.53
# 56                                     Grenade                      45.70
# 59                                      Guinée                       4.08
# 60                               Guinée-Bissau                       2.16
# 63                                       Haïti                       8.91
# 80                                    Kiribati                      17.98
# 89                                  Madagascar                       2.87
# 91                                      Malawi                       5.17
# 92                                    Maldives                      13.50
# 93                                        Mali                       2.83
# 97                                  Mauritanie                       5.14
# 99                                    Mongolie                       2.77
# 101                                 Mozambique                       3.59
# 108                         Nouvelle-Calédonie                      38.71
# 110                                      Népal                       1.99
# 113                                Ouzbékistan                       1.96
# 122                                      Pérou                      13.47
# 126                  République centrafricaine                       2.29
# 130      République démocratique populaire lao                      10.91
# 132                République-Unie de Tanzanie                       1.88
# 134            Saint-Vincent-et-les Grenadines                      72.31
# 135                               Sainte-Lucie                      56.69
# 137                       Sao Tomé-et-Principe                       9.47
# 142                                     Soudan                       1.60
# 148                                Tadjikistan                       4.45
# 152                                Timor-Leste                       4.24
# 156                               Turkménistan                       4.52
# 160                                    Vanuatu                      11.66
# 165                                   Zimbabwe                       4.68
# 170                                   Éthiopie                       0.13
#
# Élément  Disponibilité intérieure  Exportations  Importations  Production  \
# 0                            57.0           0.0          29.0        28.0
# 13                           26.0           8.0          24.0         6.0
# 14                          250.0          -1.0           0.0       249.0
# 23                           46.0           0.0           0.0        46.0
# 26                           10.0           7.0          12.0         1.0
# 27                           38.0           0.0          10.0        28.0
# 40                          342.0          -2.0         312.0        29.0
# 43                            3.0           NaN           3.0         NaN
# 54                            8.0          20.0          16.0         2.0
# 56                            8.0           0.0           7.0         1.0
# 59                           50.0           0.0          37.0        13.0
# 60                            4.0           6.0           4.0         3.0
# 63                           98.0           0.0          89.0         9.0
# 80                            2.0           0.0           1.0         1.0
# 89                           82.0          -1.0           0.0        81.0
# 91                           98.0          65.0           0.0       130.0
# 92                           12.0           NaN          12.0         NaN
# 93                           52.0          -7.0           1.0        48.0
# 97                           22.0          13.0          24.0         5.0
# 99                            9.0           2.0          10.0         0.0
# 101                         116.0          -1.0          24.0        92.0
# 108                          11.0          -2.0           9.0         1.0
# 110                          58.0           0.0           0.0        58.0
# 113                           NaN           NaN           NaN         NaN
# 122                        1523.0           NaN          60.0      1465.0
# 126                          11.0           0.0           4.0         7.0
# 130                           NaN           NaN           NaN         NaN
# 132                         108.0          -1.0           2.0       105.0
# 134                           8.0           2.0           9.0         0.0
# 135                          11.0           0.0          10.0         1.0
# 137                           2.0           2.0           2.0         1.0
# 142                          69.0           0.0           2.0        67.0
# 148                          40.0           0.0          38.0         2.0
# 152                           5.0          14.0          11.0         1.0
# 156                          27.0           4.0           9.0        20.0
# 160                           3.0           3.0           4.0         1.0
# 165                          76.0          -1.0           6.0        69.0
# 170                          14.0           1.0           1.0        14.0
#
# Élément  Variation de stock
# 0                       0.0
# 13                      4.0
# 14                      0.0
# 23                      0.0
# 26                      4.0
# 27                      0.0
# 40                     -1.0
# 43                      0.0
# 54                     10.0
# 56                      0.0
# 59                      0.0
# 60                      3.0
# 63                      0.0
# 80                      0.0
# 89                      0.0
# 91                     33.0
# 92                      0.0
# 93                     -4.0
# 97                      6.0
# 99                      1.0
# 101                    -1.0
# 108                    -1.0
# 110                     0.0
# 113                     NaN
# 122                     NaN
# 126                     0.0
# 130                     NaN
# 132                     0.0
# 134                     1.0
# 135                     0.0
# 137                     1.0
# 142                     0.0
# 148                     0.0
# 152                     7.0
# 156                     2.0
# 160                     1.0
# 165                     0.0
# 170                     0.0

# %%
df_dispovol_null[df_dispovol_null.isnull().any(axis=1)]
# Out:
# Élément                                   Pays  Disponibilité alimentaire  \
# 43                                    Djibouti                       2.68
# 92                                    Maldives                      13.50
# 113                                Ouzbékistan                       1.96
# 122                                      Pérou                      13.47
# 130      République démocratique populaire lao                      10.91
#
# Élément  Disponibilité intérieure  Exportations  Importations  Production  \
# 43                            3.0           NaN           3.0         NaN
# 92                           12.0           NaN          12.0         NaN
# 113                           NaN           NaN           NaN         NaN
# 122                        1523.0           NaN          60.0      1465.0
# 130                           NaN           NaN           NaN         NaN
#
# Élément  Variation de stock
# 43                      0.0
# 92                      0.0
# 113                     NaN
# 122                     NaN
# 130                     NaN

# %%
df_dispovol_null[df_dispovol_null.isnull().any(axis=1)]
# Out:
# Élément                                   Pays  Disponibilité alimentaire  \
# 43                                    Djibouti                       2.68
# 92                                    Maldives                      13.50
# 113                                Ouzbékistan                       1.96
# 122                                      Pérou                      13.47
# 130      République démocratique populaire lao                      10.91
#
# Élément  Disponibilité intérieure  Exportations  Importations  Production  \
# 43                            3.0           NaN           3.0         NaN
# 92                           12.0           NaN          12.0         NaN
# 113                           NaN           NaN           NaN         NaN
# 122                        1523.0           NaN          60.0      1465.0
# 130                           NaN           NaN           NaN         NaN
#
# Élément  Variation de stock
# 43                      0.0
# 92                      0.0
# 113                     NaN
# 122                     NaN
# 130                     NaN

# %%
#Affectation des valeurs manquantes par les valeurs trouvées dans mes recherches
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Pérou','Exportations'] = 1
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Pérou','Importations'] = 60
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Pérou','Variation de stock'] = 0
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Ouzbékistan','Importations'] = 8
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Ouzbékistan','Disponibilité intérieure'] = 67
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Ouzbékistan','Production'] = 58
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Ouzbékistan','Variation de stock'] = -2
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Ouzbékistan','Exportations'] = 0
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Djibouti','Importations'] = 3
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'Maldives','Importations'] = 12
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'République démocratique populaire lao','Importations'] = 5
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'République démocratique populaire lao','Production'] = 33
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'République démocratique populaire lao','Variation de stock'] = 0
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'République démocratique populaire lao','Disponibilité intérieure'] = 38
df_dispovol_null.loc[df_dispovol_null['Pays'] == 'République démocratique populaire lao','Exportations'] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_dispovol_null[df_dispovol_null.isnull().any(axis=1)]
# Out:
# Élément      Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 43       Djibouti                       2.68                       3.0
# 92       Maldives                      13.50                      12.0
#
# Élément  Exportations  Importations  Production  Variation de stock
# 43                NaN           3.0         NaN                 0.0
# 92                NaN          12.0         NaN                 0.0

# %%
#Il reste toujours 4 valeurs manquantes pour l'exportation et la production des Maldives et Djibouti 
#que je vais remplacer par 0
df_dispovol_null=df_dispovol_null.fillna(0)
df_dispovol_null.head()
# Out:
# Élément          Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 0         Afghanistan                       1.53                      57.0
# 13            Bahamas                      43.17                      26.0
# 14         Bangladesh                       1.50                     250.0
# 23       Burkina Faso                       2.27                      46.0
# 26         Cabo Verde                      17.62                      10.0
#
# Élément  Exportations  Importations  Production  Variation de stock
# 0                 0.0          29.0        28.0                 0.0
# 13                8.0          24.0         6.0                 4.0
# 14               -1.0           0.0       249.0                 0.0
# 23                0.0           0.0        46.0                 0.0
# 26                7.0          12.0         1.0                 4.0

# %%
df_dispovol_null[df_dispovol_null.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pays, Disponibilité alimentaire, Disponibilité intérieure, Exportations, Importations, Production, Variation de stock]
# Index: []

# %%
df_dispovol.head()
# Out:
# Élément            Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 0           Afghanistan                       1.53                      57.0
# 1        Afrique du Sud                      35.69                    2118.0
# 2               Albanie                      16.36                      47.0
# 3               Algérie                       6.38                     277.0
# 4             Allemagne                      19.47                    1739.0
#
# Élément  Exportations  Importations  Production  Variation de stock
# 0                 NaN          29.0        28.0                 0.0
# 1                63.0         514.0      1667.0                 0.0
# 2                 0.0          38.0        13.0                 4.0
# 3                 0.0           2.0       275.0                 0.0
# 4               646.0         842.0      1514.0               -29.0

# %%
df_dispovol=df_dispovol.dropna()

# %%
df_dispovol=df_dispovol.append(df_dispovol_null)

# %%
df_dispovol[df_dispovol.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pays, Disponibilité alimentaire, Disponibilité intérieure, Exportations, Importations, Production, Variation de stock]
# Index: []

# %%
df_dispovol.sort_values(by='Pays', ascending=True).head()
# Out:
# Élément            Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 0           Afghanistan                       1.53                      57.0
# 1        Afrique du Sud                      35.69                    2118.0
# 2               Albanie                      16.36                      47.0
# 3               Algérie                       6.38                     277.0
# 4             Allemagne                      19.47                    1739.0
#
# Élément  Exportations  Importations  Production  Variation de stock
# 0                 0.0          29.0        28.0                 0.0
# 1                63.0         514.0      1667.0                 0.0
# 2                 0.0          38.0        13.0                 4.0
# 3                 0.0           2.0       275.0                 0.0
# 4               646.0         842.0      1514.0               -29.0

# %%
df_pop2017[df_pop2017.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pays, Population]
# Index: []

# %% [markdown]
# Pas de valeur manquante dans la table population

# %%
df_pibind[df_pibind['PIB/Hab'].isna()]
# Out:
# Produit                                        Pays  PIB/Hab  \
# 5                                           Andorre      NaN
# 40                        Chine, Taiwan Province de      NaN
# 47                                             Cuba      NaN
# 64                                        Groenland      NaN
# 141                       République arabe syrienne      NaN
# 148      République populaire démocratique de Corée      NaN
# 154                               Samoa américaines      NaN
# 164                                   Soudan du Sud      NaN
# 185          Venezuela (République bolivarienne du)      NaN
# 187                                           Yémen      NaN
# 193                                        Érythrée      NaN
#
# Produit  Indice de stabilité
# 5                       1.42
# 40                      0.86
# 47                      0.65
# 64                      1.92
# 141                    -2.62
# 148                    -0.50
# 154                     1.22
# 164                    -2.45
# 185                    -1.25
# 187                    -2.94
# 193                    -0.73

# %%
#Affectation des valeurs manquantes par les valeurs trouvées dans mes recherches
df_pibind.loc[df_pibind['Pays'] == 'Andorre','PIB/Hab'] = 56352.2
df_pibind.loc[df_pibind['Pays'] == 'Chine, Taiwan Province de','PIB/Hab'] = 48500.8
df_pibind.loc[df_pibind['Pays'] == 'Samoa américaines','PIB/Hab'] = 5668
df_pibind.loc[df_pibind['Pays'] == 'Soudan du Sud','PIB/Hab'] = 888.8
df_pibind.loc[df_pibind['Pays'] == 'Yémen','PIB/Hab'] = 2150
df_pibind.loc[df_pibind['Pays'] == 'Érythrée','PIB/Hab'] = 1537.5

# %%
#Il reste toujours des valeurs manquantes pour 6 pays pour les 2 variables PIB par habitant et l'indice de Stabilité politique 
#que je vais remplacer par 0
df_pibind=df_pibind.fillna(0)
df_pibind.head()
# Out:
# Produit            Pays  PIB/Hab  Indice de stabilité
# 0           Afghanistan   2058.4                -2.80
# 1        Afrique du Sud  12701.3                -0.28
# 2               Albanie  12771.0                 0.38
# 3               Algérie  11737.4                -0.92
# 4             Allemagne  52952.9                 0.59

# %%
df_pibind[df_pibind.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pays, PIB/Hab, Indice de stabilité]
# Index: []

# %% [markdown]
# # <a name="C6"><font color='LightSeaGreen'>Unicité de la clé primaire</font></a>

# %%
#Creation d'une fonction qui teste l'unicité d'une colonne
def cle_primaire(df,col):
    if len(df)==len(df[col].unique()):
        print('La variable', col, 'est une clé primaire')
    else: 
        print('La variable', col, 'n\'est pas une clé primaire')

# %%
cle_primaire(df_dispovol,'Pays')
cle_primaire(df_pop2017,'Pays')
cle_primaire(df_pibind,'Pays')
# Out:
# La variable Pays est une clé primaire
# La variable Pays est une clé primaire
# La variable Pays est une clé primaire

# %% [markdown]
# # <a name="C7"><font color='LightSeaGreen'>Analyse des doublons</font></a>

# %%
#Fonction qui detecte les doublons
def detect_doublons(df):
    doub=df[df[df.columns].duplicated(subset=None, keep='first')]
    print('------------------') 
    print('La table contient', len(doub), 'doublons.')
    print(doub.shape)
    print('\n') 
    print(doub)
    print('\n')

# %%
print('------------------') 
print('Table disponibilité alimentaire')
detect_doublons(df_dispovol)
print('------------------') 
print('Table population')
detect_doublons(df_pop2017)
print('------------------') 
print('Table pib indice')
detect_doublons(df_pibind)
# Out:
# ------------------
# Table disponibilité alimentaire
# ------------------
# La table contient 0 doublons.
# (0, 7)
#
#
# Empty DataFrame
# Columns: [Pays, Disponibilité alimentaire, Disponibilité intérieure, Exportations, Importations, Production, Variation de stock]
# Index: []
#
#
# ------------------
# Table population
# ------------------
# La table contient 0 doublons.
# (0, 2)
#
#
# Empty DataFrame
# Columns: [Pays, Population]
# Index: []
#
#
# ------------------
# Table pib indice
# ------------------
# La table contient 0 doublons.
# (0, 3)
#
#
# Empty DataFrame
# Columns: [Pays, PIB/Hab, Indice de stabilité]
# Index: []

# %% [markdown]
# # <a name="C8"><font color='LightSeaGreen'>Jointure des tables</font></a>

# %%
#Jointure externe complète entre disponibilité alimentaire et population
df_dispop=pd.merge(df_dispovol, df_pop2017, left_on='Pays', right_on='Pays', how='outer', indicator=True)
df_dispop.head()
# Out:
#              Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 0  Afrique du Sud                      35.69                    2118.0
# 1         Albanie                      16.36                      47.0
# 2         Algérie                       6.38                     277.0
# 3       Allemagne                      19.47                    1739.0
# 4          Angola                      10.56                     319.0
#
#    Exportations  Importations  Production  Variation de stock  Population  \
# 0          63.0         514.0      1667.0                 0.0  57009756.0
# 1           0.0          38.0        13.0                 4.0   2884169.0
# 2           0.0           2.0       275.0                 0.0  41389189.0
# 3         646.0         842.0      1514.0               -29.0  82658409.0
# 4           0.0         277.0        42.0                 0.0  29816766.0
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both

# %%
df_dispop[df_dispop.isnull().any(axis=1)]
# Out:
#                             Pays  Disponibilité alimentaire  \
# 172                      Andorre                        NaN
# 173                     Anguilla                        NaN
# 174  Antilles néerlandaises (ex)                        NaN
# 175                        Aruba                        NaN
# 176                      Bahreïn                        NaN
# ..                           ...                        ...
# 231                      Somalie                        NaN
# 232                Soudan du Sud                        NaN
# 233                     Tokélaou                        NaN
# 234                        Tonga                        NaN
# 235                       Tuvalu                        NaN
#
#      Disponibilité intérieure  Exportations  Importations  Production  \
# 172                       NaN           NaN           NaN         NaN
# 173                       NaN           NaN           NaN         NaN
# 174                       NaN           NaN           NaN         NaN
# 175                       NaN           NaN           NaN         NaN
# 176                       NaN           NaN           NaN         NaN
# ..                        ...           ...           ...         ...
# 231                       NaN           NaN           NaN         NaN
# 232                       NaN           NaN           NaN         NaN
# 233                       NaN           NaN           NaN         NaN
# 234                       NaN           NaN           NaN         NaN
# 235                       NaN           NaN           NaN         NaN
#
#      Variation de stock  Population      _merge
# 172                 NaN     77001.0  right_only
# 173                 NaN     14584.0  right_only
# 174                 NaN    275186.0  right_only
# 175                 NaN    105366.0  right_only
# 176                 NaN   1494076.0  right_only
# ..                  ...         ...         ...
# 231                 NaN  14589179.0  right_only
# 232                 NaN  10910763.0  right_only
# 233                 NaN      1300.0  right_only
# 234                 NaN    101998.0  right_only
# 235                 NaN     11370.0  right_only
#
# [64 rows x 9 columns]

# %%
#Suppression des pays qui n'ont aucune information dans la table disponibilité alimentaire
df_dispop=df_dispop.drop(df_dispop[df_dispop['_merge']=='right_only'].index)
df_dispop.head()
# Out:
#              Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 0  Afrique du Sud                      35.69                    2118.0
# 1         Albanie                      16.36                      47.0
# 2         Algérie                       6.38                     277.0
# 3       Allemagne                      19.47                    1739.0
# 4          Angola                      10.56                     319.0
#
#    Exportations  Importations  Production  Variation de stock  Population  \
# 0          63.0         514.0      1667.0                 0.0  57009756.0
# 1           0.0          38.0        13.0                 4.0   2884169.0
# 2           0.0           2.0       275.0                 0.0  41389189.0
# 3         646.0         842.0      1514.0               -29.0  82658409.0
# 4           0.0         277.0        42.0                 0.0  29816766.0
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both

# %%
df_dispop[df_dispop.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pays, Disponibilité alimentaire, Disponibilité intérieure, Exportations, Importations, Production, Variation de stock, Population, _merge]
# Index: []

# %%
#Jointure externe complète entre dispop et la table du PIB et de la stabilité politique
df_final=pd.merge(df_dispop, df_pibind, left_on='Pays', right_on='Pays', how='outer')
df_final
# Out:
#                Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 0    Afrique du Sud                      35.69                    2118.0
# 1           Albanie                      16.36                      47.0
# 2           Algérie                       6.38                     277.0
# 3         Allemagne                      19.47                    1739.0
# 4            Angola                      10.56                     319.0
# ..              ...                        ...                       ...
# 196   Soudan du Sud                        NaN                       NaN
# 197           Tonga                        NaN                       NaN
# 198          Tuvalu                        NaN                       NaN
# 199        Érythrée                        NaN                       NaN
# 200   Îles Marshall                        NaN                       NaN
#
#      Exportations  Importations  Production  Variation de stock  Population  \
# 0            63.0         514.0      1667.0                 0.0  57009756.0
# 1             0.0          38.0        13.0                 4.0   2884169.0
# 2             0.0           2.0       275.0                 0.0  41389189.0
# 3           646.0         842.0      1514.0               -29.0  82658409.0
# 4             0.0         277.0        42.0                 0.0  29816766.0
# ..            ...           ...         ...                 ...         ...
# 196           NaN           NaN         NaN                 NaN         NaN
# 197           NaN           NaN         NaN                 NaN         NaN
# 198           NaN           NaN         NaN                 NaN         NaN
# 199           NaN           NaN         NaN                 NaN         NaN
# 200           NaN           NaN         NaN                 NaN         NaN
#
#     _merge  PIB/Hab  Indice de stabilité
# 0     both  12701.3                -0.28
# 1     both  12771.0                 0.38
# 2     both  11737.4                -0.92
# 3     both  52952.9                 0.59
# 4     both   7310.9                -0.33
# ..     ...      ...                  ...
# 196    NaN    888.8                -2.45
# 197    NaN   6467.1                 0.79
# 198    NaN   3896.7                 1.24
# 199    NaN   1537.5                -0.73
# 200    NaN   3706.3                 0.87
#
# [201 rows x 11 columns]

# %%
df_final[df_final.isnull().any(axis=1)].head()
# Out:
#                     Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 28   Chine, continentale                      12.33                   18161.0
# 96   Polynésie française                      47.40                      15.0
# 155   Nouvelle-Calédonie                      38.71                      11.0
# 172              Andorre                        NaN                       NaN
# 173              Bahreïn                        NaN                       NaN
#
#      Exportations  Importations  Production  Variation de stock    Population  \
# 28          576.0         452.0     18236.0               -50.0  1.421022e+09
# 96            0.0          15.0         1.0                 0.0  2.761020e+05
# 155          -2.0           9.0         1.0                -1.0  2.771500e+05
# 172           NaN           NaN         NaN                 NaN           NaN
# 173           NaN           NaN         NaN                 NaN           NaN
#
#     _merge  PIB/Hab  Indice de stabilité
# 28    both      NaN                  NaN
# 96    both      NaN                  NaN
# 155   both      NaN                  NaN
# 172    NaN  56352.2                 1.42
# 173    NaN  47709.8                -0.96

# %%
#Suppression des pays qui n'ont aucune information dans la table disponibilité alimentaire
df_final=df_final.dropna()
df_final
# Out:
#                Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 0    Afrique du Sud                      35.69                    2118.0
# 1           Albanie                      16.36                      47.0
# 2           Algérie                       6.38                     277.0
# 3         Allemagne                      19.47                    1739.0
# 4            Angola                      10.56                     319.0
# ..              ...                        ...                       ...
# 167     Timor-Leste                       4.24                       5.0
# 168    Turkménistan                       4.52                      27.0
# 169         Vanuatu                      11.66                       3.0
# 170        Zimbabwe                       4.68                      76.0
# 171        Éthiopie                       0.13                      14.0
#
#      Exportations  Importations  Production  Variation de stock   Population  \
# 0            63.0         514.0      1667.0                 0.0   57009756.0
# 1             0.0          38.0        13.0                 4.0    2884169.0
# 2             0.0           2.0       275.0                 0.0   41389189.0
# 3           646.0         842.0      1514.0               -29.0   82658409.0
# 4             0.0         277.0        42.0                 0.0   29816766.0
# ..            ...           ...         ...                 ...          ...
# 167          14.0          11.0         1.0                 7.0    1243258.0
# 168           4.0           9.0        20.0                 2.0    5757667.0
# 169           3.0           4.0         1.0                 1.0     285510.0
# 170          -1.0           6.0        69.0                 0.0   14236595.0
# 171           1.0           1.0        14.0                 0.0  106399924.0
#
#     _merge  PIB/Hab  Indice de stabilité
# 0     both  12701.3                -0.28
# 1     both  12771.0                 0.38
# 2     both  11737.4                -0.92
# 3     both  52952.9                 0.59
# 4     both   7310.9                -0.33
# ..     ...      ...                  ...
# 167   both   3145.5                 0.07
# 168   both  14205.0                -0.13
# 169   both   3081.8                 0.70
# 170   both   3274.6                -0.71
# 171   both   2021.6                -1.68
#
# [169 rows x 11 columns]

# %%
#suppression de la colonne _merge
df_final=df_final.drop(['_merge'], axis = 1)

# %%
df_final.head()
# Out:
#              Pays  Disponibilité alimentaire  Disponibilité intérieure  \
# 0  Afrique du Sud                      35.69                    2118.0
# 1         Albanie                      16.36                      47.0
# 2         Algérie                       6.38                     277.0
# 3       Allemagne                      19.47                    1739.0
# 4          Angola                      10.56                     319.0
#
#    Exportations  Importations  Production  Variation de stock  Population  \
# 0          63.0         514.0      1667.0                 0.0  57009756.0
# 1           0.0          38.0        13.0                 4.0   2884169.0
# 2           0.0           2.0       275.0                 0.0  41389189.0
# 3         646.0         842.0      1514.0               -29.0  82658409.0
# 4           0.0         277.0        42.0                 0.0  29816766.0
#
#    PIB/Hab  Indice de stabilité
# 0  12701.3                -0.28
# 1  12771.0                 0.38
# 2  11737.4                -0.92
# 3  52952.9                 0.59
# 4   7310.9                -0.33

# %%
#récupère les lignes où l'exportation est négative
df_final[df_final['Exportations']<0]
# Out:
#                             Pays  Disponibilité alimentaire  \
# 136                   Bangladesh                       1.50
# 140                         Cuba                      23.72
# 148                   Madagascar                       2.87
# 151                         Mali                       2.83
# 154                   Mozambique                       3.59
# 161  République-Unie de Tanzanie                       1.88
# 170                     Zimbabwe                       4.68
#
#      Disponibilité intérieure  Exportations  Importations  Production  \
# 136                     250.0          -1.0           0.0       249.0
# 140                     342.0          -2.0         312.0        29.0
# 148                      82.0          -1.0           0.0        81.0
# 151                      52.0          -7.0           1.0        48.0
# 154                     116.0          -1.0          24.0        92.0
# 161                     108.0          -1.0           2.0       105.0
# 170                      76.0          -1.0           6.0        69.0
#
#      Variation de stock   Population  PIB/Hab  Indice de stabilité
# 136                 0.0  159685424.0   4160.7                -1.26
# 140                -1.0   11339254.0      0.0                 0.65
# 148                 0.0   25570512.0   1584.4                -0.30
# 151                -4.0   18512430.0   2246.8                -1.91
# 154                -1.0   28649018.0   1283.7                -0.93
# 161                 0.0   54660339.0   2530.6                -0.56
# 170                 0.0   14236595.0   3274.6                -0.71

# %%
#remplace les valeurs négatives de l'exportation par 0
df_final['Exportations']=df_final['Exportations'].apply(lambda x: 0 if x < 0 else x)

# %%
df_final[df_final['Exportations']<0]
# Out:
# Empty DataFrame
# Columns: [Pays, Disponibilité alimentaire, Disponibilité intérieure, Exportations, Importations, Production, Variation de stock, Population, PIB/Hab, Indice de stabilité]
# Index: []

# %% [markdown]
# # <a name="C9"><font color='LightSeaGreen'>Indicateurs choisis</font></a>

# %% [markdown]
# 1.   Disponibilité d'aliments dans chaque pays en kg/personne/an
# 2.   Importations (Milliers de tonnes)
# 3.   Production (Milliers de tonnes)
# 4.   Population : si le nombre d'habitants est grand, la probabilité que les habitants consomment du poulet est plus grande, alors il serait plus intéressant d'y envoyer notre poulet
# 5.   PIB/Habitant ($) : si le PIB d'un pays est fort, cela indique un niveau economique élevé du pays en moyenne, donc la consommation de poulet pourrait y être plus élevée
# 6.   Indice de stabilité politique
# (-2.5 : faible stabilité politique (min) / 2.5 : forte stabilité politique (max)) : une instabilité politique dans un pays empêcherait l'importation de poulet

# %%
df_final=df_final[['Pays', 'Disponibilité alimentaire', 'Importations', 'Production', 'Population', 'PIB/Hab', 'Indice de stabilité']]
df_final.head()
# Out:
#              Pays  Disponibilité alimentaire  Importations  Production  \
# 0  Afrique du Sud                      35.69         514.0      1667.0
# 1         Albanie                      16.36          38.0        13.0
# 2         Algérie                       6.38           2.0       275.0
# 3       Allemagne                      19.47         842.0      1514.0
# 4          Angola                      10.56         277.0        42.0
#
#    Population  PIB/Hab  Indice de stabilité
# 0  57009756.0  12701.3                -0.28
# 1   2884169.0  12771.0                 0.38
# 2  41389189.0  11737.4                -0.92
# 3  82658409.0  52952.9                 0.59
# 4  29816766.0   7310.9                -0.33

# %% [markdown]
# # **<font color='indianred'>Partie 3 : Analyse univariée des indicateurs</font>**

# %% [markdown]
# # <a name="C10"><font color='LightSeaGreen'>Disponibilité alimentaire</font></a>

# %%
#Représentation la variable Disponibilité alimentaire sous forme de boxplot
plt.figure(figsize=(12, 3))
sns.set(style="darkgrid")
sns.boxplot(x=df_final["Disponibilité alimentaire"], color="b")
plt.title('Distribution de la variable Disponibilité alimentaire')
plt.savefig("distribution_dispo_al_boxplot.png")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#détecte les outliers et les filtre pour avoir un nouveau dataframe sans outliers
#1er quartile
q1 = df_final['Disponibilité alimentaire'].quantile(0.25)
#3eme quartile
q3 = df_final['Disponibilité alimentaire'].quantile(0.75)
#écart interquatile
iqr = q3 - q1
print('Ecart interquatile =', round(iqr,2))
seuil_min = q1 -(1.5 * iqr) 
seuil_max = q3 +(1.5 * iqr)
print('Seuil minimum =', round(seuil_min,2))
print('Seuil maximum =', round(seuil_max,2))
#affiche le dataframe final sans outliers
df_out = df_final[(df_final['Disponibilité alimentaire'] > seuil_min) & (df_final['Disponibilité alimentaire'] < seuil_max)]
#trie par ordre croissant les donnees du df web sans outliers via la colonne 'disponibilité alimentaire' 
#df_out.sort_values('Disponibilité alimentaire', ascending=True).head()
#dataframe des outliers
dfo = df_final[(df_final['Disponibilité alimentaire'] < seuil_min) | (df_final['Disponibilité alimentaire'] > seuil_max)]
#liste des outliers
liste_out=(dfo['Disponibilité alimentaire'].tolist())
print('Nombre doutliers:', len(liste_out))
print('Liste des outliers :', liste_out)
print('\n')
#affichage des outliers 
dfo[['Pays','Disponibilité alimentaire']].sort_values(by='Disponibilité alimentaire', ascending=True)
# Out:
# Ecart interquatile = 22.95
# Seuil minimum = -28.04
# Seuil maximum = 63.76
# Nombre doutliers: 3
# Liste des outliers : [67.39, 64.77, 72.31]
#                                 Pays  Disponibilité alimentaire
# 106                            Samoa                      64.77
# 59                            Israël                      67.39
# 162  Saint-Vincent-et-les Grenadines                      72.31

# %%
#distribution de la variable disponibilité alimentaire sous forme de courbe
plt.figure(figsize=(15, 5))
sns.set(style="darkgrid")
sns.kdeplot(df_final['Disponibilité alimentaire'], shade=True, bw_method=0.5, color="blue")
plt.title('Distribution de la variable Disponibilité alimentaire')
plt.xlabel('Disponibilité alimentaire')
plt.ylabel('Fréquence d\'apparition')
plt.savefig("distribution_dispo_al.png")
plt.show()

# %% [markdown]
# # <a name="C11"><font color='LightSeaGreen'>Importations</font></a>

# %%
#utilisation de la librairie Seaborn pour representer la variable disponibilité alimentaire sous forme de boxplot
plt.figure(figsize=(20, 3))
sns.set(style="darkgrid")
sns.boxplot(x=df_final["Importations"], color="r")
plt.title('Importations')
plt.savefig("distribution_import_boxplot.png")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#liste vide
outliers=[]

#fonction qui détecte, compte et liste les outliers
def liste_outliers(df):
    #seuil des valeurs aberrantes : +/- 3  
    threshold=3
    #moyenne
    mean=np.mean(df)
    #écart-type
    std=np.std(df)
    for i in df:
        zscore=(i-mean)/std
        if np.abs(zscore)>threshold:
            outliers.append(i)
    return outliers

#appel de la fonction 
l1=liste_outliers(df_final['Importations'])
print('Nombre d\'outliers :', len(l1))
print('\n') 
print('Liste des outliers : ', l1)
# Out:
# Nombre d'outliers : 6
#
#
# Liste des outliers :  [842.0, 722.0, 907.0, 1069.0, 972.0, 779.0]

# %%
#détecte les outliers et les filtre pour avoir un nouveau dataframe sans outliers
#1er quartile
q1 = df_final['Importations'].quantile(0.25)
#3eme quartile
q3 = df_final['Importations'].quantile(0.75)
#écart interquatile
iqr = q3 - q1
print('Ecart interquatile =', round(iqr,2))
seuil_min = q1 -(1.5 * iqr) 
seuil_max = q3 +(1.5 * iqr)
print('Seuil minimum =', round(seuil_min,2))
print('Seuil maximum =', round(seuil_max,2))
#affiche le dataframe final sans outliers
df_out = df_final[(df_final['Importations'] > seuil_min) & (df_final['Importations'] < seuil_max)]
#trie par ordre croissant les donnees du df sans outliers via la colonne 'Importations' 
#df_out.sort_values('Disponibilité alimentaire', ascending=True).head()

#dataframe des outliers
dfo = df_final[(df_final['Importations'] < seuil_min) | (df_final['Importations'] > seuil_max)]
#liste des outliers
liste_out=(dfo['Importations'].tolist())
print('Nombre doutliers:', len(liste_out))
print('Liste des outliers :', liste_out)
print('\n')
#affichage des outliers 
dfo[['Pays','Importations']].sort_values(by='Importations', ascending=False)
# Out:
# Ecart interquatile = 76.0
# Seuil minimum = -111.0
# Seuil maximum = 193.0
# Nombre doutliers: 18
# Liste des outliers : [514.0, 842.0, 277.0, 722.0, 338.0, 907.0, 205.0, 506.0, 226.0, 470.0, 1069.0, 972.0, 608.0, 249.0, 779.0, 291.0, 433.0, 312.0]
#                                                   Pays  Importations
# 62                                               Japon        1069.0
# 79                                             Mexique         972.0
# 25                            Chine - RAS de Hong-Kong         907.0
# 3                                            Allemagne         842.0
# 99   Royaume-Uni de Grande-Bretagne et d'Irlande du...         779.0
# 6                                      Arabie saoudite         722.0
# 93                                            Pays-Bas         608.0
# 0                                       Afrique du Sud         514.0
# 43                                              France         506.0
# 56                                                Iraq         470.0
# 130                                Émirats arabes unis         433.0
# 13                                            Belgique         338.0
# 140                                               Cuba         312.0
# 126                                           Viet Nam         291.0
# 4                                               Angola         277.0
# 94                                         Philippines         249.0
# 44                                Fédération de Russie         226.0
# 38                                             Espagne         205.0

# %%
#distribution de la variable importation sous forme de courbe
plt.figure(figsize=(15, 5))
sns.set(style="darkgrid")
sns.kdeplot(df_final['Importations'], shade=True, bw_method=0.5, color="red")
plt.title('Distribution de la variable Importations')
plt.xlabel('Importations')
plt.ylabel('Fréquence d\'apparition')
plt.savefig("distribution_import.png")
plt.show()

# %%
#Courbe de Lorenz sur l'importation par pays
#Sélection du sous-échantillon de travail que l'on appelle import_pays
plt.figure(figsize=(12, 5))
import_pays = df_final['Importations'].values

#On place les observations dans une variable
#Tri des individus dans l'ordre croissant des valeurs de la variable, 
#Calcul de la somme cumulée et normalisation en divisant par la somme des observations
lorenz_import_pays = np.cumsum(np.sort(import_pays)) / import_pays.sum()

plt.plot(np.linspace(0,1,len(lorenz_import_pays)), lorenz_import_pays, drawstyle='steps-post', color='brown', label='Lorenz')
plt.fill_between(np.linspace(0,1,len(lorenz_import_pays)) ,lorenz_import_pays , color='#777ecd')
plt.plot([0, 1], [0, 1], 'g-', lw=2, label='Distribution égalitaire')
plt.vlines(x=.76, ymin=0, ymax=.5, color='red', linestyle='--', linewidth=1, label='Medial')
plt.hlines(xmin=.76, xmax=0, y=.5, color='red', linestyle='--', linewidth=1)

plt.title('Courbe de Lorenz de la quantité d\'importation par pays')
plt.xlabel("Distribution des pays (%)")
plt.ylabel("Cumul de la quantité d'importation (%)")
plt.legend(loc="best")

plt.savefig("lorenz_import_pays.png")
plt.show()

#Mesure de l'aire entre la 1ere bissectrice et la courbe de Lorenz 
#Calcul de l'indice de Gini
aire_import_pays=(lorenz_import_pays.sum()-(lorenz_import_pays[-1]/2)-(lorenz_import_pays[0]/2))/(len(lorenz_import_pays))
S_import_pays=0.5-aire_import_pays
gini_import_pays=2*S_import_pays
print('Coefficient de Gini=', round(gini_import_pays,2))
# Out:
# Coefficient de Gini= 0.77

# %% [markdown]
# 20% des pays font 80% de l'importation totale (Loi de Pareto 80/20)

# %% [markdown]
# # <a name="C12"><font color='LightSeaGreen'>Production</font></a>

# %%
#utilisation de la librairie Seaborn pour representer la variable production sous forme de boxplot
plt.figure(figsize=(20, 3))
sns.set(style="darkgrid")
sns.boxplot(x=df_final["Production"], color="g")
plt.title('Production')
plt.savefig("distribution_prod_boxplot.png")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#liste vide
outliers=[]

#appel de la fonction 
l1=liste_outliers(df_final['Production'])
print('Nombre d\'outliers :', len(l1))
print('\n') 
print('Liste des outliers : ', l1)
#affichage des outliers
# Out:
# Nombre d'outliers : 2
#
#
# Liste des outliers :  [14201.0, 21914.0]

# %%
df_final[['Pays','Production']].sort_values(by='Production', ascending=False).head(2)
# Out:
#                       Pays  Production
# 132  États-Unis d'Amérique     21914.0
# 18                  Brésil     14201.0

# %% [markdown]
# Les deux plus grand producteurs de poulet sont les US et le Brésil.

# %%
#distribution de la variable Production sous forme de courbe
plt.figure(figsize=(15, 5))
sns.set(style="darkgrid")
sns.kdeplot(df_final['Production'], shade=True, bw_method=0.5, color="green")
plt.title('Distribution de la variable Production')
plt.xlabel('Production')
plt.ylabel('Fréquence d\'apparition')
plt.savefig("distribution_prod.png")
plt.show()

# %% [markdown]
# # <a name="C12"><font color='LightSeaGreen'>Population</font></a>

# %%
#utilisation de la librairie Seaborn pour representer la variable population sous forme de boxplot
plt.figure(figsize=(20, 3))
sns.set(style="darkgrid")
sns.boxplot(x=df_final["Population"], color="m")
plt.title('Population')
plt.savefig("distribution_pop_boxplot.png")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_final[['Pays','Population']].sort_values(by='Population', ascending=False).head(20)
# Out:
#                                                   Pays    Population
# 53                                                Inde  1.338677e+09
# 132                              États-Unis d'Amérique  3.250848e+08
# 54                                           Indonésie  2.646510e+08
# 90                                            Pakistan  2.079062e+08
# 18                                              Brésil  2.078338e+08
# 85                                             Nigéria  1.908732e+08
# 136                                         Bangladesh  1.596854e+08
# 44                                Fédération de Russie  1.455301e+08
# 62                                               Japon  1.275027e+08
# 79                                             Mexique  1.247773e+08
# 171                                           Éthiopie  1.063999e+08
# 94                                         Philippines  1.051729e+08
# 129                                             Égypte  9.644259e+07
# 126                                           Viet Nam  9.460065e+07
# 3                                            Allemagne  8.265841e+07
# 122                                            Turquie  8.111645e+07
# 55                      Iran (République islamique d')  8.067388e+07
# 118                                          Thaïlande  6.920981e+07
# 99   Royaume-Uni de Grande-Bretagne et d'Irlande du...  6.672746e+07
# 43                                              France  6.484251e+07

# %% [markdown]
# # <a name="C14"><font color='LightSeaGreen'>PIB/Habitant</font></a>

# %%
#utilisation de la librairie Seaborn pour representer la variable population sous forme de boxplot
plt.figure(figsize=(20, 3))
sns.set(style="darkgrid")
sns.boxplot(x=df_final["PIB/Hab"], color="lightblue")
plt.title('PIB/Habitant')
plt.savefig("distribution_pop_boxplot.png")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df_final[['Pays','PIB/Hab']].sort_values(by='PIB/Hab', ascending=False).head()
# Out:
#                      Pays   PIB/Hab
# 26   Chine - RAS de Macao  126184.0
# 73             Luxembourg  112308.0
# 57                Irlande   78655.6
# 112                Suisse   69103.6
# 130   Émirats arabes unis   67183.6

# %% [markdown]
# # <a name="C15"><font color='LightSeaGreen'>Indice de stabilité politique</font></a>

# %%
#distribution de la variable Production sous forme de courbe
plt.figure(figsize=(15, 5))
sns.set(style="darkgrid")
sns.kdeplot(df_final['Indice de stabilité'], shade=True, bw_method=0.5, color="lightpink")
plt.title('Distribution de la variable Indice de Stabilité politique')
plt.xlabel('Stabilité politique')
plt.ylabel('Fréquence d\'apparition')
plt.savefig("distribution_stab_po.png")
plt.show()

# %%
df_final[['Pays','Indice de stabilité']].sort_values(by='Indice de stabilité', ascending=False).head(20)
# Out:
#                      Pays  Indice de stabilité
# 87       Nouvelle-Zélande                 1.59
# 26   Chine - RAS de Macao                 1.43
# 58                Islande                 1.35
# 73             Luxembourg                 1.33
# 112                Suisse                 1.26
# 76                  Malte                 1.25
# 36              Dominique                 1.20
# 106                 Samoa                 1.18
# 86                Norvège                 1.17
# 97               Portugal                 1.12
# 62                  Japon                 1.11
# 23                 Canada                 1.10
# 42               Finlande                 1.08
# 124               Uruguay                 1.05
# 10               Autriche                 1.05
# 17               Botswana                 1.02
# 143               Grenade                 1.01
# 117              Tchéquie                 1.00
# 57                Irlande                 1.00
# 163          Sainte-Lucie                 0.99

# %%
# Tranches d'indice de stabilité politique
#df_final['classe_indice'] = 'Pays instable'
#df_final['classe_indice'].loc[df_final[df_final['Indice de stabilité']>=0].index] = 'Pays stable'
#df_final['classe_indice'].loc[df_final[df_final['Indice de stabilité']>=1].index] = 'Pays très stable'

#df_final.head()

# %% [markdown]
# # **<font color='indianred'>Partie 4 : Analyse bivariée des indicateurs</font>**

# %% [markdown]
# On distingue 3 groupes d'indicateurs:
#
# 1er groupe :
# *   Disponibilité alimentaire
# *   Importations
# *   Production
#
# 2ème groupe : Population
#
# 3ème groupe :
# *   PIB/ Habitant
# *   Indice de stabilité politique

# %% [markdown]
# # <a name="C16"><font color='LightSeaGreen'>Disponibilité alimentaire / Importations</font></a>

# %%
#Visualizing the data - displot
plt.figure(figsize=(19,5))
plot_dispo = sns.distplot(df_final["Disponibilité alimentaire"])
plot_import = sns.distplot(df_final["Importations"])
plt.xlabel('Disponibilité / Importations')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Disponibilité / Importations')

# %% [markdown]
# Question : Les importations dependent-elles de la disponibilité alimentaire ? Réponse: Oui/Non
#
# H0 : les importations ne dépendent pas de la disponibilité alimentaire
# H1 : les importations dépendent de la disponibilité alimentaire

# %%
plt.figure(figsize=(12,4))
sns.regplot(data=df_final, x="Disponibilité alimentaire", y="Importations",fit_reg=False, scatter_kws={"color":"purple","alpha":1.0,"s":50})
plt.xlabel('Disponibilité alimentaire')
plt.ylabel('Importations')
plt.title('Corrélation entre Disponibilité et Importations')
plt.savefig("dispo_imp.png")
plt.show()

# %%
#Test  de Pearson : calcul du coefficient de corrélation de Pearson et de la p-value
from scipy.stats import pearsonr 
CorrAgeMontant = pd.DataFrame(pearsonr(df_final['Disponibilité alimentaire'], df_final['Importations']),index=['Pearson_coeff','p-value'],columns=['resultat_test']) 
CorrAgeMontant
# Out:
#                resultat_test
# Pearson_coeff       0.198541
# p-value             0.009662

# %%
#Test de Spearman
st.spearmanr(df_final['Disponibilité alimentaire'], df_final['Importations'])
# Out:
# SpearmanrResult(correlation=0.3709187632946707, pvalue=6.891224638209332e-07)

# %% [markdown]
# p-value < 0.05 => Il y a une dépendance entre la disponibilité alimentaire et les importations.

# %% [markdown]
# # <a name="C17"><font color='LightSeaGreen'>Disponibilité alimentaire / Production</font></a>

# %%
plt.figure(figsize=(12,4))
sns.regplot(data=df_final, x="Disponibilité alimentaire", y="Production",fit_reg=False, scatter_kws={"color":"blue","alpha":1.0,"s":50})
plt.xlabel('Disponibilité alimentaire')
plt.ylabel('Production')
plt.title('Relation entre Disponibilité et Production')
plt.savefig("dispo_prod.png")
plt.show()

# %%
#Test  de Pearson : calcul du coefficient de corrélation de Pearson et de la p-value
from scipy.stats import pearsonr 
CorrAgeMontant = pd.DataFrame(pearsonr(df_final['Disponibilité alimentaire'], df_final['Production']),index=['Pearson_coeff','p-value'],columns=['resultat_test']) 
CorrAgeMontant
# Out:
#                resultat_test
# Pearson_coeff       0.262974
# p-value             0.000552

# %%
#Test de Spearman
st.spearmanr(df_final['Disponibilité alimentaire'], df_final['Production'])
# Out:
# SpearmanrResult(correlation=0.23204167448451068, pvalue=0.0023997930170858864)

# %% [markdown]
# p-value < 0.05  =>  Dépendance entre la disponibilité alimentaire et la production.

# %% [markdown]
# # <a name="C18"><font color='LightSeaGreen'>Importations / Production</font></a>

# %%
plt.figure(figsize=(12,4))
sns.regplot(data=df_final, x='Importations', y="Production",fit_reg=False, scatter_kws={"color":"brown","alpha":1.0,"s":50})
plt.xlabel('Importations')
plt.ylabel('Production')
plt.title('Relation entre Importations et Production')
plt.savefig("imp_prod.png")
plt.show()

# %%
#Test  de Pearson : calcul du coefficient de corrélation de Pearson et de la p-value
from scipy.stats import pearsonr 
CorrAgeMontant = pd.DataFrame(pearsonr(df_final['Importations'], df_final['Production']),index=['Pearson_coeff','p-value'],columns=['resultat_test']) 
CorrAgeMontant
# Out:
#                resultat_test
# Pearson_coeff       0.136074
# p-value             0.077724

# %%
#Test de Spearman
st.spearmanr(df_final['Importations'], df_final['Production'])
# Out:
# SpearmanrResult(correlation=0.26861071374604634, pvalue=0.00041376529315489513)

# %% [markdown]
# Il y a corrélation entre les deux variables importations et production.

# %% [markdown]
# # <a name="C19"><font color='LightSeaGreen'>Importations / Population</font></a>

# %%
plt.figure(figsize=(12,4))
sns.regplot(data=df_final, x="Importations", y="Population",fit_reg=False, scatter_kws={"color":"red","alpha":1.0,"s":50})
plt.xlabel('Importations')
plt.ylabel('Population')
plt.title('Relation entre Importations et Population')
plt.savefig("imp_pop.png")
plt.show()

# %%
#Test  de Pearson : calcul du coefficient de corrélation de Pearson et de la p-value
from scipy.stats import pearsonr 
CorrAgeMontant = pd.DataFrame(pearsonr(df_final['Importations'], df_final['Population']),index=['Pearson_coeff','p-value'],columns=['resultat_test']) 
CorrAgeMontant
# Out:
#                resultat_test
# Pearson_coeff       0.065624
# p-value             0.396607

# %%
#Test de Spearman
st.spearmanr(df_final['Importations'], df_final['Population'])
# Out:
# SpearmanrResult(correlation=0.15743311486530195, pvalue=0.04093314502314371)

# %% [markdown]
# Pas de corrélation entre les importations et la population des pays.

# %% [markdown]
# # <a name="C20"><font color='LightSeaGreen'>Indice de stabilité politique / PIB par Habitant</font></a>

# %%
plt.figure(figsize=(12,4))
sns.regplot(data=df_final, x="Indice de stabilité", y="PIB/Hab",fit_reg=False, scatter_kws={"color":"lightblue","alpha":1.0,"s":50})
plt.xlabel('Indice de stabilité')
plt.ylabel('PIB/Hab')
plt.title('Relation entre Indice de stabilité et PIB/Hab')
plt.savefig("ind_pib.png")
plt.show()

# %%
#Test  de Pearson : calcul du coefficient de corrélation de Pearson et de la p-value
from scipy.stats import pearsonr 
CorrAgeMontant = pd.DataFrame(pearsonr(df_final['Indice de stabilité'], df_final['PIB/Hab']),index=['Pearson_coeff','p-value'],columns=['resultat_test']) 
CorrAgeMontant
# Out:
#                resultat_test
# Pearson_coeff   5.623221e-01
# p-value         1.781591e-15

# %%
#Test de Spearman
st.spearmanr(df_final['Indice de stabilité'], df_final['PIB/Hab'])
# Out:
# SpearmanrResult(correlation=0.6204404247943031, pvalue=2.3305290287345097e-19)

# %% [markdown]
# Il y a une forte corrélation entre l'indice de stabilité politique et le PIB par habitant.

# %% [markdown]
# # **<font color='indianred'>Partie 5 : CAH, Kmeans et ACP</font>**

# %%
df_final=df_final.set_index('Pays')

# %% [markdown]
# Je supprime les variables Population et Production car les EU et le Brésil ont des valeurs très supérieures aux autres pays.

# %%
df_final=df_final[['Disponibilité alimentaire',	'Importations',	'PIB/Hab',	'Indice de stabilité']]
df_final.head(1)
# Out:
#                 Disponibilité alimentaire  Importations  PIB/Hab  \
# Pays
# Afrique du Sud                      35.69         514.0  12701.3
#
#                 Indice de stabilité
# Pays
# Afrique du Sud                -0.28

# %%
from google.colab import files
functions = files.upload()
# Out:
#      <input type="file" id="files-0f8a752a-1b14-4951-a19f-ff8e8719570b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f8a752a-1b14-4951-a19f-ff8e8719570b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving functions.py to functions (5).py

# %% [markdown]
# # <a name="C20"><font color='LightSeaGreen'>Classification Ascendante Hiérarchique</font></a>

# %%
from functions import plot_dendrogram
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn import preprocessing

# préparation des données pour le clustering
X = df_final
nom_pays = df_final.index

# %%
# Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# Clustering hiérarchique
Z = linkage(X_scaled, 'ward')

# Affichage du dendrogramme
plot_dendrogram(Z, nom_pays)

# %%
#Avant normalisation
pd.DataFrame(X,columns=X.columns).plot(kind='density',sharex=True,figsize=(12,5),layout=(10,1))

# %%
#Après normalisation
pd.DataFrame(X_scaled,columns=X.columns).plot(kind='density',sharex=True,figsize=(12,5),layout=(10,1))

# %%
# Create a hierarchical clustering model
from sklearn.cluster import AgglomerativeClustering

hiercluster = AgglomerativeClustering(affinity='euclidean', linkage='ward', compute_full_tree=True) 
hiercluster
# Out:
# AgglomerativeClustering(compute_full_tree=True)

# %%
# Fit the data to the model and determine which clusters each data point belongs to:
hiercluster.set_params(n_clusters=3)
clusters = hiercluster.fit_predict(X_scaled) 
np.bincount(clusters) # count of data points in each cluster
# Out:
# array([77, 81, 11])

# %%
# Read off 5 clusters:
hiercluster.set_params(n_clusters=5)
clusters = hiercluster.fit_predict(X_scaled) 
np.bincount(clusters) # count of data points in each cluster
# Out:
# array([81, 20, 11, 45, 12])

# %%
# Add cluster number to the original data
X_scaled_clustered = pd.DataFrame(X_scaled, columns=X.columns, index=X.index)
X_scaled_clustered['cluster'] = clusters

X_scaled_clustered.head()
# Out:
#                 Disponibilité alimentaire  Importations   PIB/Hab  \
# Pays
# Afrique du Sud                   0.997552      2.311494 -0.349436
# Albanie                         -0.230621     -0.267183 -0.346070
# Algérie                         -0.864721     -0.462209 -0.395991
# Allemagne                       -0.033021      4.088398  1.594637
# Angola                          -0.599136      1.027573 -0.609782
#
#                 Indice de stabilité  cluster
# Pays
# Afrique du Sud            -0.240717        2
# Albanie                    0.494485        0
# Algérie                   -0.953639        0
# Allemagne                  0.728412        2
# Angola                    -0.296414        3

# %%
# Find the size of the clusters
X_scaled_clustered["cluster"].value_counts()
# Out:
# 0    81
# 3    45
# 1    20
# 4    12
# 2    11
# Name: cluster, dtype: int64

# %%
# Show a dendrogram, just for the smallest cluster
from scipy.cluster.hierarchy import linkage, fcluster 

sample = X_scaled_clustered[X_scaled_clustered.cluster==3]
Z = linkage(sample, 'ward') 
names = sample.index 
plot_dendrogram(Z, names)

# %% [markdown]
# # <a name="C20"><font color='LightSeaGreen'>Analyse en Composantes Principales (PCA)</font></a>

# %%
from sklearn.decomposition import PCA
from sklearn import decomposition, preprocessing

n_comp=4

# Création du PCA pour réduire les données à 2 dimensions pour la visualisation
pca = PCA(n_components=n_comp)
pca.fit(X_scaled)

# Cercle des corrélations
from functions import display_circles
pcs = pca.components_
display_circles(pcs, n_comp, pca, [(0,1)], labels = np.array(df_final.columns))

# Projection des individus (nouvel espace vectoriel)
X_projected = pca.transform(X_scaled)

# Affiche un scatter plot des points des data dans le nouvel espace vectoriel
from functions import display_factorial_planes
display_factorial_planes(X_projected, n_comp, pca, [(0,1)], labels=None, illustrative_var = clusters, alpha = 0.8)

# Eboulis des valeurs propres
from functions import display_scree_plot
display_scree_plot(pca)

plt.show()

# %%
# Add the cluster number to the original scaled data
X_clustered = pd.DataFrame(X_scaled, index=X.index, columns=X.columns)
X_clustered["cluster"] = clusters

# Display parallel coordinates plots, one for each cluster
#from functions import parallel_coordinates
from functions import display_parallel_coordinates
display_parallel_coordinates(X_clustered, 5)

# %%
#Variance of the data explained by each of the 4 principal components, 
#starting with PC1, the principal component that explains most of the variance.
pca.explained_variance_ratio_
# Out:
# array([0.51991038, 0.23199374, 0.15071888, 0.09737699])

# %%
#if we sum up the values in this array they will equal 1,
#indicating that the 4 principal components together explain 100% of the variance of the data.
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.51991038, 0.75190412, 0.90262301, 1.        ])

# %%
#Moyenne de chaque variable dans chaque cluster
means =  X_clustered.groupby(by="cluster").mean()
means
# Out:
#          Disponibilité alimentaire  Importations   PIB/Hab  \
# cluster
# 0                        -0.639565     -0.337275 -0.611549
# 1                         0.838201     -0.035048  1.931368
# 2                         0.496359      3.332426  0.969341
# 3                         0.116532     -0.080103  0.053934
# 4                         2.028071     -0.419321 -0.181804
#
#          Indice de stabilité
# cluster
# 0                  -0.727826
# 1                   1.085988
# 2                   0.131947
# 3                   0.558846
# 4                   0.886221

# %%
from functions import display_parallel_coordinates_centroids
display_parallel_coordinates_centroids(means.reset_index(), 5)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# BOXPLOTS

# %%
X_clustered.boxplot(by="cluster", figsize=(15,10), layout=(2,5))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f070d8a3f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f070d880690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f070c9cc8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f070d3bc890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f070cc61a10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f070ca11f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f070cd2d4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f070cce1910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f070cce1950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f070d81ff50>]],
#       dtype=object)

# %% [markdown]
# # <a name="C20"><font color='LightSeaGreen'>K-Means</font></a>

# %%
# préparation des données pour le clustering
X = df_final
nom_pays = df_final.index
# Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# %%
# Import the kmeans algorithm
from sklearn.cluster import KMeans

# Create a k-means clustering model
kmeans = KMeans(init='random', n_clusters=5, n_init=10)

# Fit the data to the model
kmeans.fit(X_scaled)

# Determine which clusters each data point belongs to:
clusters =  kmeans.predict(X_scaled)
clusters
# Out:
# array([0, 4, 3, 0, 4, 2, 0, 2, 4, 2, 1, 3, 2, 1, 4, 2, 4, 4, 2, 4, 4, 4,
#        3, 1, 2, 0, 1, 1, 1, 4, 4, 4, 4, 3, 1, 2, 4, 1, 1, 4, 4, 1, 0, 4,
#        4, 4, 4, 4, 2, 4, 4, 1, 3, 4, 3, 3, 1, 1, 2, 1, 2, 0, 4, 4, 3, 4,
#        2, 4, 4, 3, 4, 1, 1, 4, 2, 1, 4, 2, 0, 4, 3, 4, 4, 3, 3, 1, 1, 1,
#        3, 3, 2, 4, 0, 3, 2, 1, 4, 0, 4, 1, 4, 2, 3, 2, 2, 4, 4, 1, 1, 4,
#        1, 2, 1, 4, 3, 1, 3, 3, 2, 3, 3, 3, 4, 3, 4, 3, 4, 3, 0, 4, 2, 4,
#        3, 2, 3, 3, 4, 4, 4, 3, 4, 2, 3, 3, 3, 4, 4, 4, 4, 3, 3, 4, 3, 3,
#        4, 4, 3, 4, 3, 2, 2, 4, 3, 3, 4, 4, 4, 3, 3], dtype=int32)

# %%
# Add cluster number to the original data
X_scaled_clustered = pd.DataFrame(X_scaled, columns=X.columns, index=X.index)
X_scaled_clustered['cluster'] = clusters

X_scaled_clustered.head()
# Out:
#                 Disponibilité alimentaire  Importations   PIB/Hab  \
# Pays
# Afrique du Sud                   0.997552      2.311494 -0.349436
# Albanie                         -0.230621     -0.267183 -0.346070
# Algérie                         -0.864721     -0.462209 -0.395991
# Allemagne                       -0.033021      4.088398  1.594637
# Angola                          -0.599136      1.027573 -0.609782
#
#                 Indice de stabilité  cluster
# Pays
# Afrique du Sud            -0.240717        0
# Albanie                    0.494485        4
# Algérie                   -0.953639        3
# Allemagne                  0.728412        0
# Angola                    -0.296414        4

# %%
# Run a number of tests, for 1, 2, ... num_clusters
num_clusters = 5
kmeans_tests = [KMeans(n_clusters=i, init='random', n_init=10) for i in range(1, num_clusters)]
score = [kmeans_tests[i].fit(X_scaled).score(X_scaled) for i in range(len(kmeans_tests))]

# Plot the curve
plt.plot(range(1, num_clusters),score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
from sklearn.decomposition import PCA
# Create a PCA model to reduce our data to 2 dimensions for visualisation
pca = PCA(n_components=2)
pca.fit(X_scaled)

# Transfor the scaled data to the new PCA space
X_reduced = pca.transform(X_scaled)

# %%
# Convert to a data frame
X_reduceddf = pd.DataFrame(X_reduced, index=X.index, columns=['PC1','PC2'])
X_reduceddf['cluster'] = clusters
X_reduceddf.head()
# Out:
#                      PC1       PC2  cluster
# Pays
# Afrique du Sud  0.913027  2.017147        0
# Albanie        -0.136246 -0.406961        4
# Algérie        -1.340369  0.092183        3
# Allemagne       2.607819  3.440657        0
# Angola         -0.497532  1.130959        4

# %%
centres_reduced = pca.transform(kmeans.cluster_centers_)
centres_reduced
# Out:
# array([[ 2.43413145,  2.90423308],
#        [ 1.59488021, -0.48050466],
#        [ 1.18225719, -0.77167086],
#        [-1.61479291,  0.37278517],
#        [-0.47375727, -0.1822225 ]])

# %%
display_factorial_planes(X_reduced, 2, pca, [(0,1)], illustrative_var = clusters, alpha = 0.8)
plt.scatter(centres_reduced[:, 0], centres_reduced[:, 1],
            marker='x', s=169, linewidths=3,
            color='r', zorder=10)

# %%
# Add the cluster number to the original scaled data
X_clustered = pd.DataFrame(X_scaled, index=X.index, columns=X.columns)
X_clustered["cluster"] = clusters

# Display parallel coordinates plots, one for each cluster
display_parallel_coordinates(X_clustered, 5)

# %%
# Create a data frame containing our centroids
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
centroids['cluster'] = centroids.index

display_parallel_coordinates_centroids(centroids, 6)
# Out:
# No handles with labels found to put in legend.
